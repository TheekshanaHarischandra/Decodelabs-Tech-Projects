# %%
total = 0
while True:
    new_expenses = (input("Enter expenses or done"))
    if new_expenses == "done":
        break
    

    try:
        total = total + float(new_expenses)
    except ValueError:
        print("Entered valeu is not a number")
print("Total expenses: ",total)
