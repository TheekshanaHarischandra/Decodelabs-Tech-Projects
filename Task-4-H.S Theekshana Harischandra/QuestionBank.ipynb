# %%
marks = 0
print("What is the highest mountain in Sri Lanka")
N = str(input("Answer: "))
if (N == "Piduruthalagala")or(N == "piduruthalagala"):
    marks = marks+1
    print("")
else:
    print ("Wrong answer")
    print("")
print("What is the highest water fall in Sri Lanka")
N = str(input("Answer: "))
if(N == "Babarakanda Ella") or (N == "babarakanda ella"):
    marks += 1
    print("")
else:
    print("wrong answer")
    print("")
print("What is the longest river in Sri Lanka")
N = str(input("Answer: "))
if (N == "Mahaweli") or (N == "mahaweli"):
    marks += 1
    print("")
else:
    print("Wrong answer")
    print("")

print ("Total Marks " , marks)
# Out:
# What is the highest mountain in Sri Lanka
# Answer:  piduruthalagala
# What is the highest water fall in Sri Lanka
# Answer:  babarakanda ella
# What is the longest river in Sri Lanka
# Answer:  mahaweli
# Total Marks  3
